# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd

# %%
link = 'https://books.toscrape.com/catalogue/page-1.html'

# %%
res = requests.get(link)

# %%
soup = BeautifulSoup(res.text , "html.parser")

# %%
data = []
for i in soup.find_all("li" , class_ = "col-xs-6 col-sm-4 col-md-3 col-lg-3"):
    img_link = "https://books.toscrape.com/" + i.find("img").get("src")[-3]
    book_title = i.find_all("a")[-1].get("title")
    book_link = "https://books.toscrape.com/catalogue/" + i.find_all("a")[-1].get("href")
    rating = i.find("p").get("class")[-1]
    price = i.find("p" , class_ = "price_color").text[1:]
    stock = i.find("p" , class_ = "instock availability").text
    
    data.append([book_title,price,rating,img_link,stock,book_link])

# %%
df = pd.DataFrame(data , columns = ["book_title" , "price" , "rating" , "img_link" , "stock" , "book_link"])

# %%
df.head(10)
# Out:
#                                           book_title   price rating  \
# 0                               A Light in the Attic  £51.77  Three
# 1                                 Tipping the Velvet  £53.74    One
# 2                                         Soumission  £50.10    One
# 3                                      Sharp Objects  £47.82   Four
# 4              Sapiens: A Brief History of Humankind  £54.23   Five
# 5                                    The Requiem Red  £22.65    One
# 6  The Dirty Little Secrets of Getting Your Dream...  £33.34   Four
# 7  The Coming Woman: A Novel Based on the Life of...  £17.93  Three
# 8  The Boys in the Boat: Nine Americans and Their...  £22.60   Four
# 9                                    The Black Maria  £52.15    One
#
#                        img_link                               stock  \
# 0  https://books.toscrape.com/j  \n\n    \n        In stock\n    \n
# 1  https://books.toscrape.com/j  \n\n    \n        In stock\n    \n
# 2  https://books.toscrape.com/j  \n\n    \n        In stock\n    \n
# 3  https://books.toscrape.com/j  \n\n    \n        In stock\n    \n
# 4  https://books.toscrape.com/j  \n\n    \n        In stock\n    \n
# 5  https://books.toscrape.com/j  \n\n    \n        In stock\n    \n
# 6  https://books.toscrape.com/j  \n\n    \n        In stock\n    \n
# 7  https://books.toscrape.com/j  \n\n    \n        In stock\n    \n
# 8  https://books.toscrape.com/j  \n\n    \n        In stock\n    \n
# 9  https://books.toscrape.com/j  \n\n    \n        In stock\n    \n
#
#                                            book_link
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# 4  https://books.toscrape.com/catalogue/sapiens-a...
# 5  https://books.toscrape.com/catalogue/the-requi...
# 6  https://books.toscrape.com/catalogue/the-dirty...
# 7  https://books.toscrape.com/catalogue/the-comin...
# 8  https://books.toscrape.com/catalogue/the-boys-...
# 9  https://books.toscrape.com/catalogue/the-black...

# %%
df.to_csv("books_data_scraped_from_single_page.csv")
